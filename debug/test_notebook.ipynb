# %%
import matplotlib.pyplot as plt
import numpy as np 
from mpl_bsic import apply_bsic_style, export_figure, add_title_subtitle

# %%
import logging

logging.getLogger('mpl_bsic').handlers
# Out:
# []

# %%
import logging 
logging.getLogger('mpl_bsic').setLevel(logging.DEBUG)
x = np.linspace(0,10,100)
y = np.sin(x)

fig, ax = plt.subplots(2,2, figsize=(8,8))
ax[0,0].plot(x,y)
ax[0,0].set_title('Sin(x)')

# fig.savefig('test.svg', dpi=1200, bbox_inches='tight')
apply_bsic_style(fig)
title = 'Sin and Cosin of X'
subtitle = 'Yu can see from the figure how the sin and cosin of x are just shifted versions of each other. We will now do some further analysis on this'
fig.subplots_adjust(top=0.9)
ann1, ann2 = add_title_subtitle(fig, title, subtitle)

export_figure(fig, 'test.png')
# Out:
# adding fonts to font manager
# base dir:  /Users/andreafranceschini/PycharmProjects/mpl_bsic/mpl_bsic
# fonts dir:  /Users/andreafranceschini/PycharmProjects/mpl_bsic/mpl_bsic/fonts

# %%
x = np.linspace(0,10,100)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.set_title('Sin(x)')

# fig.savefig('test.svg', dpi=1200, bbox_inches='tight')
apply_bsic_style(fig)
title = 'Sin and Cosin of X'
subtitle = 'Yu can see from the figure how the sin and cosin of x are just shifted versions of each other. We will now do some further analysis on this'
fig.subplots_adjust(top=0.9)
ann1, ann2 = add_title_subtitle(fig, title, subtitle)
# # txt = ax[0,0].text(0,ax[0,0].get_ylim()[1],subtitle, ha='left', va='center', wrap=True)
# width = ax[0,0].bbox.width * 2
# width = ax[0,0].get_tightbbox().width
# print(width)
# ann1._get_wrap_line_width = lambda : width
# 
# bbox = fig.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
# print(bbox.width * fig.dpi)
fig.tight_layout()
fig.savefig('test.png') 
# export_figure(fig, 'final')
# Out:
# fonts already added so will not add again
# new width lim: 480.0
# subtitle_annotation height = 34.39999999999998,
# new text pos = (0, 49.39999999999998)
